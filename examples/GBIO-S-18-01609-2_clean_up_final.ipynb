# %% [markdown]
# # Comparative analysis of sequencing technologies for single-cell transcriptomics
# ## Abstract
# Single-cell RNA-seq technologies require library preparation prior to sequencing. Here, we present the first report to compare the cheaper BGISEQ-500 platform to the Illumina HiSeq platform for scRNA-seq. We generate a resource of 468 single cells and 1297 matched single cDNA samples, performing SMARTer and Smart-seq2 protocols on two cell lines with RNA spike-ins. We sequence these libraries on both platforms using single- and paired-end reads. The platforms have comparable sensitivity and accuracy in terms of quantification of gene expression, and low technical variability. Our study provides a standardized scRNA-seq resource to benchmark new scRNA-seq library preparation protocols and sequencing platforms.

# %% [markdown]
# # Data proccessing

# %% [markdown]
# ** SCQUA is a python package that we developed for analyzing the single cell RNA Sequencing quality.**

# %%
# %pylab inline

import warnings
warnings.filterwarnings("ignore")
from SCQUA import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ls ../
# Out:
# Figs/     data/     docs/     examples/ jup/      pdata/    pdata1/   supinfo/

# %% [markdown]
# > Figs include the resulted figures
# > data include all the raw data
# > jup include the jupyter notebook to process the data and make the figures
# > pdata include all the processed data.

# %%
ls ../data/
# Out:
# ASE_stat.csv                bgi_tpm.csv.gz
# AS_stat.xls                 coverage_bgi.csv
# AS_stat_e6.csv              coverage_sanger.csv
# GRCm38.cdna.all.symbol.tsv  fLen_bgi.csv
# PlurinetGenes_Category.txt  fLen_sanger.csv
# bgi_263_722_ann.xlsx        phn.csv
# bgi_cts.csv.gz              sanger.csv
# bgi_ds_e4_cts.csv.gz        sanger_cts.csv.gz
# bgi_ds_e4_qc.csv.gz         sanger_ds_e4_cts.csv.gz
# bgi_ds_e4_tpm.csv.gz        sanger_ds_e4_qc.csv.gz
# bgi_ds_e5_cts.csv.gz        sanger_ds_e4_tpm.csv.gz
# bgi_ds_e5_qc.csv.gz         sanger_ds_e5_cts.csv.gz
# bgi_ds_e5_tpm.csv.gz        sanger_ds_e5_qc.csv.gz
# bgi_ds_e6_cts.csv.gz        sanger_ds_e5_tpm.csv.gz
# bgi_ds_e6_qc.csv.gz         sanger_ds_e6_cts.csv.gz
# bgi_ds_e6_tpm.csv.gz        sanger_ds_e6_qc.csv.gz
# bgi_qc.csv.gz               sanger_ds_e6_tpm.csv.gz
# bgi_se_cts.csv.gz           sanger_qc.csv.gz
# bgi_se_qc.csv.gz            sanger_tpm.csv.gz
# bgi_se_tpm.csv.gz

# %% [markdown]
# [Salmon](https://salmon.readthedocs.io/en/latest/salmon.html) outputs 3 information, the counts, tpm and qc metrics. We concatenate these information in \*cts.gz, \*tpm.gz and \*qc.gz.
#
# detection limit (sensitivity) and accuracy based on spike-ins can be calculated.

# %%
ercc = get_ERCC()
sirv = get_SIRV()
spike = pd.concat([ercc,sirv])

# %% [markdown]
# ** This is the part to generate Table S2-S6.**

# %%
for f in iglob('../data/*_tpm.csv.gz'):
    name = f.split('/')[-1].replace('_tpm.csv.gz',"")
    print(name)
    cts = pd.read_csv(f.replace('tpm','cts'), index_col=0)
    tpm = pd.read_csv(f, index_col=0)
    phn = pd.read_csv(f.replace('tpm','qc'), index_col=0)
    df = get_result(tpm, ercc, sirv, spike)
    phn = pd.concat([phn,df,cts.loc[cts.index.str.startswith("ENS")].T], axis=1)
    phn["Total_counts"] = cts.loc[cts.index.str.startswith("ENS")].sum()
    phn["study"] = name
    phn.to_csv("../pdata/%s.csv"%name)
# Out:
# sanger_ds_e4
# sanger
# sanger_ds_e6
# bgi_ds_e5
# sanger_ds_e5
# bgi
# bgi_se
# bgi_ds_e6
# bgi_ds_e4

# %% [markdown]
# ** Table S7. This file is annotation of the all the cells sequenced.**

# %%
phn = pd.read_csv("../data/phn.csv",index_col=0)

# %%
phn.head()
# Out:
#               Batch  Cell Cell_line   Fullname Place    Platform Protocol  \
# ERR1901831  SMARTer     2       ESC  SMARTer_2    UK  HiSeq-2000  SMARTer
# ERR1901830  SMARTer     1       ESC  SMARTer_1    UK  HiSeq-2000  SMARTer
# ERR1901832  SMARTer     3       ESC  SMARTer_3    UK  HiSeq-2000  SMARTer
# ERR1901833  SMARTer     4       ESC  SMARTer_4    UK  HiSeq-2000  SMARTer
# ERR1901834  SMARTer     5       ESC  SMARTer_5    UK  HiSeq-2000  SMARTer
#
#                      Protocol2 Read_type Well   repeat
# ERR1901831  HiSeq-2000 SMARTer        PE  UNK  SMARTer
# ERR1901830  HiSeq-2000 SMARTer        PE  UNK  SMARTer
# ERR1901832  HiSeq-2000 SMARTer        PE  UNK  SMARTer
# ERR1901833  HiSeq-2000 SMARTer        PE  UNK  SMARTer
# ERR1901834  HiSeq-2000 SMARTer        PE  UNK  SMARTer

# %%
phn.tail()
# Out:
#                               Batch  Cell Cell_line            Fullname  \
# Index_CWHPEI17060082  ESC_AR_P101_H     8       ESC  ESC_A111_P101_H_08
# Index_CWHPEI17060083  ESC_AR_P101_H     9       ESC  ESC_A111_P101_H_09
# Index_CWHPEI17060084  ESC_AR_P101_H    10       ESC  ESC_A111_P101_H_10
# Index_CWHPEI17060085  ESC_AR_P101_H    11       ESC  ESC_A111_P101_H_11
# Index_CWHPEI17060086  ESC_AR_P101_H    12       ESC  ESC_A111_P101_H_12
#
#                       Place   Platform    Protocol                  Protocol2  \
# Index_CWHPEI17060082  China  Hiseq4000  Smart-Seq2  Hiseq4000 ESC Library rep
# Index_CWHPEI17060083  China  Hiseq4000  Smart-Seq2  Hiseq4000 ESC Library rep
# Index_CWHPEI17060084  China  Hiseq4000  Smart-Seq2  Hiseq4000 ESC Library rep
# Index_CWHPEI17060085  China  Hiseq4000  Smart-Seq2  Hiseq4000 ESC Library rep
# Index_CWHPEI17060086  China  Hiseq4000  Smart-Seq2  Hiseq4000 ESC Library rep
#
#                      Read_type Well           repeat
# Index_CWHPEI17060082     PE101  UNK  ESC Library rep
# Index_CWHPEI17060083     PE101  UNK  ESC Library rep
# Index_CWHPEI17060084     PE101  UNK  ESC Library rep
# Index_CWHPEI17060085     PE101  UNK  ESC Library rep
# Index_CWHPEI17060086     PE101  UNK  ESC Library rep

# %%
for f in iglob("../pdata/*.csv"):
    print(f)
    fout = f.replace("pdata","pdata1")
    df = pd.read_csv(f,index_col=0)
    df = df.loc[df.index.isin(phn.index)]
    dfp = phn.loc[df.index]
    df = pd.concat([df, dfp], axis=1)
    df.to_csv(fout)
# Out:
# ../pdata/sanger_ds_e6.csv
# ../pdata/bgi_ds_e5.csv
# ../pdata/bgi_ds_e4.csv
# ../pdata/sanger_ds_e5.csv
# ../pdata/bgi_ds_e6.csv
# ../pdata/sanger_ds_e4.csv
# ../pdata/sanger.csv
# ../pdata/bgi.csv
# ../pdata/bgi_se.csv

# %% [markdown]
# ## Fig 1B 1C
# (B) Single-cell detection limit (Sensitivity) of mESC cells, downsampled across two orders of magnitude from SMARTer and two Smart-seq2 replicates (633 samples). The single-cell sensitivities are largely similar between different library preparation across scRNA-seq protocols. (C) Single-cell accuracy of mESC cells, downsampled across two orders of magnitude for SMARTer and two Smart-seq2 replicates (633 samples). The grey dotted lines indicate downsampling at different read depths per cell, while red line indicates saturation per cell.

# %%
dfs = []
for f in iglob("../pdata1/*_ds_*"):
    df = pd.read_csv(f, index_col=0)
    df["id"] = df.index
    df.index = df.study+"_"+df.id
    df = df[["id",'Cell','Fullname','num_processed',\
             'detection_limit','accuracy','Protocol','Batch','Protocol2']+
            df.columns[df.columns.str.startswith('ENS')].tolist()]
    dfs.append(df)
df = pd.concat(dfs,axis =0)

# %%
df.shape
# Out:
# (1896, 34848)

# %%
df.head()
# Out:
#                                  id  Cell   Fullname  num_processed  \
# sanger_ds_e6_ERR1901834  ERR1901834     5  SMARTer_5        1000000
# sanger_ds_e6_ERR1901830  ERR1901830     1  SMARTer_1        1000000
# sanger_ds_e6_ERR1901832  ERR1901832     3  SMARTer_3        1000000
# sanger_ds_e6_ERR1901835  ERR1901835     6  SMARTer_6        1000000
# sanger_ds_e6_ERR1901833  ERR1901833     4  SMARTer_4        1000000
#
#                          detection_limit  accuracy Protocol    Batch  \
# sanger_ds_e6_ERR1901834        76.121794  0.500011  SMARTer  SMARTer
# sanger_ds_e6_ERR1901830       111.926773  0.613356  SMARTer  SMARTer
# sanger_ds_e6_ERR1901832        71.153016  0.632203  SMARTer  SMARTer
# sanger_ds_e6_ERR1901835        71.030314  0.682535  SMARTer  SMARTer
# sanger_ds_e6_ERR1901833        62.824744  0.628298  SMARTer  SMARTer
#
#                                   Protocol2  ENSMUSG00000107196.1  \
# sanger_ds_e6_ERR1901834  HiSeq-2000 SMARTer                   0.0
# sanger_ds_e6_ERR1901830  HiSeq-2000 SMARTer                   0.0
# sanger_ds_e6_ERR1901832  HiSeq-2000 SMARTer                   0.0
# sanger_ds_e6_ERR1901835  HiSeq-2000 SMARTer                   0.0
# sanger_ds_e6_ERR1901833  HiSeq-2000 SMARTer                   0.0
#
#                                  ...           ENSMUSG00000083997.1  \
# sanger_ds_e6_ERR1901834          ...                            0.0
# sanger_ds_e6_ERR1901830          ...                            0.0
# sanger_ds_e6_ERR1901832          ...                            0.0
# sanger_ds_e6_ERR1901835          ...                            0.0
# sanger_ds_e6_ERR1901833          ...                            0.0
#
#                          ENSMUSG00000111337.1  ENSMUSG00000109159.1  \
# sanger_ds_e6_ERR1901834               0.00000                   0.0
# sanger_ds_e6_ERR1901830               0.00000                   0.0
# sanger_ds_e6_ERR1901832               1.01072                   0.0
# sanger_ds_e6_ERR1901835               0.00000                   0.0
# sanger_ds_e6_ERR1901833               0.00000                   0.0
#
#                          ENSMUSG00000107243.1  ENSMUSG00000110425.1  \
# sanger_ds_e6_ERR1901834                   0.0                   0.0
# sanger_ds_e6_ERR1901830                   0.0                   0.0
# sanger_ds_e6_ERR1901832                   0.0                   0.0
# sanger_ds_e6_ERR1901835                   0.0                   0.0
# sanger_ds_e6_ERR1901833                   0.0                   0.0
#
#                          ENSMUSG00000066315.9  ENSMUSG00000073771.11  \
# sanger_ds_e6_ERR1901834              0.000000                8.27496
# sanger_ds_e6_ERR1901830              0.000982                5.00000
# sanger_ds_e6_ERR1901832              0.000000                6.22531
# sanger_ds_e6_ERR1901835              0.000000                0.00000
# sanger_ds_e6_ERR1901833              0.000000              101.10100
#
#                          ENSMUSG00000107035.1  ENSMUSG00000080242.5  \
# sanger_ds_e6_ERR1901834                   1.0               26.4398
# sanger_ds_e6_ERR1901830                   0.0               29.1214
# sanger_ds_e6_ERR1901832                   0.0               35.2669
# sanger_ds_e6_ERR1901835                   0.0               30.2924
# sanger_ds_e6_ERR1901833                   0.0               46.1377
#
#                          ENSMUSG00000081408.1
# sanger_ds_e6_ERR1901834                   0.0
# sanger_ds_e6_ERR1901830                   0.0
# sanger_ds_e6_ERR1901832                   0.0
# sanger_ds_e6_ERR1901835                   0.0
# sanger_ds_e6_ERR1901833                   0.0
#
# [5 rows x 34848 columns]

# %%
df=df[df.Protocol.str.startswith("S")]

# %% [markdown]
# > use only the protocols in sanger

# %%
df = df.loc[~(df.Protocol2.str.startswith('BGISEQ-500 K562')|\
              df.Protocol2.str.startswith('Hiseq4000')|\
              df.Protocol2.str.startswith('BGISEQ-500 ESC'))]

# %%
df.Protocol.value_counts()
# Out:
# Smart-Seq2    972
# SMARTer       576
# Name: Protocol, dtype: int64

# %%
df.Protocol2.value_counts()
# Out:
# BGISEQ-500 SMARTer            288
# HiSeq-2000 SMARTer            288
# HiSeq-2000 Smart-Seq2 rep1    288
# BGISEQ-500 Smart-Seq2 rep1    285
# BGISEQ-500 Smart-Seq2 rep2    216
# HiSeq-2000 Smart-Seq2 rep2    183
# Name: Protocol2, dtype: int64

# %%
df=df.replace([np.inf, -np.inf], np.nan).dropna(axis=0, how='any')

# %%
df.to_csv("../pdata1/Fig1BC.csv")

# %%
df = pd.read_csv("../pdata1/Fig1BC.csv", index_col=0)

# %%
figsize(5,5)
matplotlib.rcParams.update({'font.size': 14})
names = ['BGISEQ-500 Smart-Seq2 rep1','HiSeq-2000 Smart-Seq2 rep1', 
         'BGISEQ-500 Smart-Seq2 rep2','HiSeq-2000 Smart-Seq2 rep2', 
         'BGISEQ-500 SMARTer','HiSeq-2000 SMARTer']
ax = fit_sensitivity(df,key2="num_processed",key3='Protocol2', \
                     yscale='log', xlabel = 'Sequenced reads per single-well',\
                     ylabel = 'Detection limit \n (# of molecules)', \
                     ylim = [0, 1e4], xlim = [500, 1e8], \
                     xlabelsize = 18, ylabelsize = 18, \
                     title = 'Sensitivity', titlesize = 20, names = names)
# Out:
# np.log10(detection_limit) ~ np.power(np.log10(num_processed), 2) + np.log10(num_processed) + C(Protocol2) + 1
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     np.log10(detection_limit)   R-squared:                       0.713
# Model:                                   OLS   Adj. R-squared:                  0.712
# Method:                        Least Squares   F-statistic:                     547.6
# Date:                       Sat, 01 Dec 2018   Prob (F-statistic):               0.00
# Time:                               15:51:18   Log-Likelihood:                -209.80
# No. Observations:                       1548   AIC:                             435.6
# Df Residuals:                           1540   BIC:                             478.4
# Df Model:                                  7
# Covariance Type:                   nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# Intercept                                      9.0510      0.345     26.211      0.000       8.374       9.728
# C(Protocol2)[T.BGISEQ-500 Smart-Seq2 rep1]    -0.1199      0.023     -5.167      0.000      -0.165      -0.074
# C(Protocol2)[T.BGISEQ-500 Smart-Seq2 rep2]    -0.0703      0.025     -2.813      0.005      -0.119      -0.021
# C(Protocol2)[T.HiSeq-2000 SMARTer]             0.0790      0.023      3.413      0.001       0.034       0.124
# C(Protocol2)[T.HiSeq-2000 Smart-Seq2 rep1]     0.0037      0.023      0.161      0.872      -0.042       0.049
# C(Protocol2)[T.HiSeq-2000 Smart-Seq2 rep2]    -0.0698      0.026     -2.658      0.008      -0.121      -0.018
# np.power(np.log10(num_processed), 2)           0.1743      0.014     12.300      0.000       0.146       0.202
# np.log10(num_processed)                       -2.2506      0.141    -15.912      0.000      -2.528      -1.973
# ==============================================================================
# Omnibus:                     1287.987   Durbin-Watson:                   1.751
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            93228.151
# Skew:                           3.391   Prob(JB):                         0.00
# Kurtosis:                      40.409   Cond. No.                     1.44e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.44e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# np.log10(num_processed)                      -2.250609
# C(Protocol2)[T.BGISEQ-500 Smart-Seq2 rep1]   -0.119945
# C(Protocol2)[T.BGISEQ-500 Smart-Seq2 rep2]   -0.070343
# C(Protocol2)[T.HiSeq-2000 Smart-Seq2 rep2]   -0.069809
# C(Protocol2)[T.HiSeq-2000 Smart-Seq2 rep1]    0.003725
# C(Protocol2)[T.HiSeq-2000 SMARTer]            0.079032
# np.power(np.log10(num_processed), 2)          0.174267
# Intercept                                     9.050951
# dtype: float64
# read_satureation: 2866584

# %% [markdown]
# ** Fig 1B**

# %%
ax = fit_sensitivity(df, fun = 'accuracy',key1="accuracy",key2="num_processed",key3='Protocol2', \
                     xlabel = 'Sequenced reads per single-well',\
                     ylabel = 'Accuracy \n (pearson correlation \n coefficient)', \
                     ylim = [0, 1], xlim = [500, 1e8], \
                     xlabelsize = 18, ylabelsize = 18, \
                     title = 'Accuracy', titlesize = 20, names = names)
# Out:
# accuracy ~ np.power(np.log10(num_processed), 2) + np.log10(num_processed) + C(Protocol2) + 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               accuracy   R-squared:                       0.350
# Model:                            OLS   Adj. R-squared:                  0.347
# Method:                 Least Squares   F-statistic:                     118.4
# Date:                Sat, 01 Dec 2018   Prob (F-statistic):          3.30e-139
# Time:                        15:51:19   Log-Likelihood:                 1019.8
# No. Observations:                1548   AIC:                            -2024.
# Df Residuals:                    1540   BIC:                            -1981.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# Intercept                                     -0.9296      0.156     -5.958      0.000      -1.236      -0.624
# C(Protocol2)[T.BGISEQ-500 Smart-Seq2 rep1]     0.0515      0.010      4.914      0.000       0.031       0.072
# C(Protocol2)[T.BGISEQ-500 Smart-Seq2 rep2]     0.0075      0.011      0.666      0.505      -0.015       0.030
# C(Protocol2)[T.HiSeq-2000 SMARTer]             0.0119      0.010      1.140      0.255      -0.009       0.032
# C(Protocol2)[T.HiSeq-2000 Smart-Seq2 rep1]     0.0336      0.010      3.209      0.001       0.013       0.054
# C(Protocol2)[T.HiSeq-2000 Smart-Seq2 rep2]     0.0287      0.012      2.421      0.016       0.005       0.052
# np.power(np.log10(num_processed), 2)          -0.0378      0.006     -5.903      0.000      -0.050      -0.025
# np.log10(num_processed)                        0.4839      0.064      7.571      0.000       0.359       0.609
# ==============================================================================
# Omnibus:                       56.216   Durbin-Watson:                   2.061
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               61.865
# Skew:                          -0.490   Prob(JB):                     3.68e-14
# Kurtosis:                       2.992   Cond. No.                     1.44e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.44e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept                                    -0.929621
# np.power(np.log10(num_processed), 2)         -0.037794
# C(Protocol2)[T.BGISEQ-500 Smart-Seq2 rep2]    0.007529
# C(Protocol2)[T.HiSeq-2000 SMARTer]            0.011925
# C(Protocol2)[T.HiSeq-2000 Smart-Seq2 rep2]    0.028737
# C(Protocol2)[T.HiSeq-2000 Smart-Seq2 rep1]    0.033581
# C(Protocol2)[T.BGISEQ-500 Smart-Seq2 rep1]    0.051542
# np.log10(num_processed)                       0.483914
# dtype: float64
# read_satureation: 2523440

# %% [markdown]
# ** Fig 1C**

# %% [markdown]
# ## Fig 1D 1E

# %% [markdown]
#  (D) PCA for matched single-cell cDNA samples performed using SMARTer and two replicates of Smart-seq2 and sequenced across both sequencing platforms. Red and green colored circles indicate sequencing of matched cDNA on Illumina HiSeq2500 and BGISEQ-500 respectively. The dotted lines represent distance i.e. measure of similarity across sequencing platforms. (E) Single-cell correlations for each scRNA-seq protocol and across sequencing platforms. The correlations (R=0.52~0.70) are comparable between sequencing platforms.

# %%
df = pd.read_csv("../pdata1/Fig1BC.csv", index_col=0)

# %% [markdown]
# ** Fig 1D**

# %%
i=0
protocols = ['Smart-Seq2 rep1','Smart-Seq2 rep2','SMARTer']
for df1, df2 in zip(dfs1, dfs2):
    plt.clf()
    plot_Fig1D(df1, df2, protocol = protocols[i], xlabelsize = 18, ylabelsize=18, titlesize = 18)
    plt.show()
    i+=1
# Out:
#  /Users/zmiao/bin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: DataConversionWarning:Data with input dtype float32 were all converted to float64 by the scale function.
#  /Users/zmiao/bin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: DataConversionWarning:Data with input dtype float32 were all converted to float64 by the scale function.
#  /Users/zmiao/bin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: DataConversionWarning:Data with input dtype float32 were all converted to float64 by the scale function.

# %% [markdown]
# ** Fig1E**

# %%
figsize(5,5)
dfs1 = []
dfs2 = []
for p, l in zip(['Smart-Seq2 rep1','Smart-Seq2 rep2','SMARTer'],[230, 120, 210]):
    df1, df2 = plot_Fig1E(df, protocol = p,\
        lim = l,\
        xlabel = "BGISEQ-500", ylabel="HiSeq-2000",\
        xlabelsize = 18, ylabelsize=18, titlesize = 18, legendsize = 16)
    plt.show()
    dfs1.append(df1)
    dfs2.append(df2)

# %% [markdown]
# ## Fig 2B

# %%
dfs = []
for f in iglob("../pdata1/*_ds_*"):
    df = pd.read_csv(f, index_col=0)
    df["id"] = df.index
    df.index = df.study+"_"+df.id
    df = df[["id",'Cell','Fullname','num_processed',\
             'detection_limit_ERCC','accuracy_ERCC','Protocol','Batch','Protocol2']+
            df.columns[df.columns.str.startswith('ENS')].tolist()]
    dfs.append(df)
df = pd.concat(dfs,axis =0)

# %%
df.shape
# Out:
# (1896, 34848)

# %%
df.Protocol.value_counts()
# Out:
# Smart-Seq2    1320
# SMARTer        576
# Name: Protocol, dtype: int64

# %%
df.Protocol2.value_counts()
# Out:
# BGISEQ-500 SMARTer                 288
# HiSeq-2000 Smart-Seq2 rep1         288
# HiSeq-2000 SMARTer                 288
# BGISEQ-500 Smart-Seq2 rep1         285
# BGISEQ-500 Smart-Seq2 rep2         216
# HiSeq-2000 Smart-Seq2 rep2         183
# Hiseq4000 K562 Sequencing rep1     111
# BGISEQ-500 K562 Seuqencing rep1    111
# Hiseq4000 ESC Sequencing rep1       63
# BGISEQ-500 ESC Sequencing rep1      63
# Name: Protocol2, dtype: int64

# %%
df['Protocol2'] = df['Protocol2'].str.replace("Seuqencing",'Sequencing')

# %%
df = df[df.Protocol2.str.find("Sequencing")>0]

# %%
df.Protocol2.value_counts()
# Out:
# BGISEQ-500 K562 Sequencing rep1    111
# Hiseq4000 K562 Sequencing rep1     111
# Hiseq4000 ESC Sequencing rep1       63
# BGISEQ-500 ESC Sequencing rep1      63
# Name: Protocol2, dtype: int64

# %%
df.to_csv("../pdata1/Fig2B.csv")

# %%
df = pd.read_csv("../pdata1/Fig2B.csv", index_col=0)

# %%
df=df.replace([np.inf, -np.inf], np.nan).dropna(axis=0, how='any')

# %% [markdown]
# ** Fig2B (Sensitivity)**

# %%
figsize(5,5)
matplotlib.rcParams.update({'font.size': 14})
names = ['BGISEQ-500 ESC Sequencing rep1', 
         'Hiseq4000 ESC Sequencing rep1', 
         'BGISEQ-500 K562 Sequencing rep1','Hiseq4000 K562 Sequencing rep1']
colors = [matplotlib.colors.rgb2hex(plt.get_cmap("Paired")(i)) for i in range(6,10)]
ax = fit_sensitivity(df,fun='np.log10(detection_limit_ERCC)', key1 ='detection_limit_ERCC',key2="num_processed",key3='Protocol2', \
                     yscale='log', xlabel = 'Sequenced reads per single-well',\
                     ylabel = 'Detection limit \n (# of molecules)', \
                     ylim = [0, 1e5], xlim = [500, 1e8], \
                     xlabelsize = 18, ylabelsize = 18, \
                     title = 'Sensitivity', titlesize = 20, names = names, colors = colors)
# Out:
# np.log10(detection_limit_ERCC) ~ np.power(np.log10(num_processed), 2) + np.log10(num_processed) + C(Protocol2) + 1
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     np.log10(detection_limit_ERCC)   R-squared:                       0.936
# Model:                                        OLS   Adj. R-squared:                  0.935
# Method:                             Least Squares   F-statistic:                     1000.
# Date:                            Sat, 01 Dec 2018   Prob (F-statistic):          1.08e-201
# Time:                                    17:31:41   Log-Likelihood:                 55.039
# No. Observations:                             348   AIC:                            -98.08
# Df Residuals:                                 342   BIC:                            -74.97
# Df Model:                                       5
# Covariance Type:                        nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                          11.8042      0.581     20.309      0.000      10.661      12.947
# C(Protocol2)[T.BGISEQ-500 K562 Sequencing rep1]    -1.0821      0.033    -32.922      0.000      -1.147      -1.017
# C(Protocol2)[T.Hiseq4000 ESC Sequencing rep1]       0.0596      0.037      1.606      0.109      -0.013       0.133
# C(Protocol2)[T.Hiseq4000 K562 Sequencing rep1]     -1.0230      0.033    -31.123      0.000      -1.088      -0.958
# np.power(np.log10(num_processed), 2)                0.2432      0.024     10.264      0.000       0.197       0.290
# np.log10(num_processed)                            -3.1457      0.237    -13.254      0.000      -3.613      -2.679
# ==============================================================================
# Omnibus:                        7.967   Durbin-Watson:                   1.806
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):               12.680
# Skew:                           0.085   Prob(JB):                      0.00176
# Kurtosis:                       3.920   Cond. No.                     1.54e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.54e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# np.log10(num_processed)                            -3.145747
# C(Protocol2)[T.BGISEQ-500 K562 Sequencing rep1]    -1.082144
# C(Protocol2)[T.Hiseq4000 K562 Sequencing rep1]     -1.023011
# C(Protocol2)[T.Hiseq4000 ESC Sequencing rep1]       0.059639
# np.power(np.log10(num_processed), 2)                0.243209
# Intercept                                          11.804248
# dtype: float64
# read_satureation: 2932078
#  /Users/zmiao/bin/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3477: UserWarning:Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.

# %% [markdown]
# ** Fig2B(Accuracy)**

# %%
ax = fit_sensitivity(df, fun = 'accuracy_ERCC',key1="accuracy_ERCC",key2="num_processed",key3='Protocol2', \
                     xlabel = 'Sequenced reads per single-well',\
                     ylabel = 'Accuracy \n (pearson correlation \n coefficient)', \
                     ylim = [0, 1], xlim = [500, 1e8], \
                     xlabelsize = 18, ylabelsize = 18, \
                     title = 'Accuracy', titlesize = 20, names = names, colors = colors)
# Out:
# accuracy_ERCC ~ np.power(np.log10(num_processed), 2) + np.log10(num_processed) + C(Protocol2) + 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          accuracy_ERCC   R-squared:                       0.393
# Model:                            OLS   Adj. R-squared:                  0.384
# Method:                 Least Squares   F-statistic:                     44.20
# Date:                Sat, 01 Dec 2018   Prob (F-statistic):           4.05e-35
# Time:                        17:33:18   Log-Likelihood:                 546.46
# No. Observations:                 348   AIC:                            -1081.
# Df Residuals:                     342   BIC:                            -1058.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                          -0.1358      0.142     -0.959      0.338      -0.414       0.143
# C(Protocol2)[T.BGISEQ-500 K562 Sequencing rep1]     0.0395      0.008      4.927      0.000       0.024       0.055
# C(Protocol2)[T.Hiseq4000 ESC Sequencing rep1]       0.0280      0.009      3.101      0.002       0.010       0.046
# C(Protocol2)[T.Hiseq4000 K562 Sequencing rep1]      0.0261      0.008      3.264      0.001       0.010       0.042
# np.power(np.log10(num_processed), 2)               -0.0302      0.006     -5.233      0.000      -0.042      -0.019
# np.log10(num_processed)                             0.3455      0.058      5.974      0.000       0.232       0.459
# ==============================================================================
# Omnibus:                       23.926   Durbin-Watson:                   1.839
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.946
# Skew:                          -0.482   Prob(JB):                     1.56e-08
# Kurtosis:                       4.244   Cond. No.                     1.54e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.54e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept                                         -0.135786
# np.power(np.log10(num_processed), 2)              -0.030211
# C(Protocol2)[T.Hiseq4000 K562 Sequencing rep1]     0.026136
# C(Protocol2)[T.Hiseq4000 ESC Sequencing rep1]      0.028049
# C(Protocol2)[T.BGISEQ-500 K562 Sequencing rep1]    0.039458
# np.log10(num_processed)                            0.345463
# dtype: float64
# read_satureation: 521794

# %% [markdown]
# # Pseudobulk

# %%
dfs = []
for f in ['bgi','sanger']:
    df = pd.read_csv("../pdata1/%s.csv"%f, index_col=0)
    dfs.append(df)
df = pd.concat(dfs, axis=0)

# %%
df.shape
# Out:
# (632, 34866)

# %%
df['Protocol2'].value_counts()
# Out:
# BGISEQ-500 SMARTer                 96
# HiSeq-2000 Smart-Seq2 rep1         96
# HiSeq-2000 SMARTer                 96
# BGISEQ-500 Smart-Seq2 rep1         95
# BGISEQ-500 Smart-Seq2 rep2         72
# HiSeq-2000 Smart-Seq2 rep2         61
# BGISEQ-500 K562 Seuqencing rep1    37
# Hiseq4000 K562 Sequencing rep1     37
# Hiseq4000 ESC Sequencing rep1      21
# BGISEQ-500 ESC Sequencing rep1     21
# Name: Protocol2, dtype: int64

# %%
df1 = df[df.columns[df.columns.str.startswith('ENS')|df.columns.str.startswith('Protocol2')]]
df1 = df1.groupby('Protocol2').sum()

# %%
df1.to_csv("../pdata1/pseudobulk.csv")

# %%
df1 = pd.read_csv("../pdata1/pseudobulk.csv", index_col=0)

# %%
df1.head(2)
# Out:
#                                  ENSMUSG00000107196.1  ENSMUSG00000106901.1  \
# Protocol2
# BGISEQ-500 ESC Sequencing rep1                    0.0                   0.0
# BGISEQ-500 K562 Seuqencing rep1                   0.5                   0.0
#
#                                  ENSMUSG00000107077.1  ENSMUSG00000097549.2  \
# Protocol2
# BGISEQ-500 ESC Sequencing rep1                 0.0000                   0.0
# BGISEQ-500 K562 Seuqencing rep1               14.0127                   0.0
#
#                                  ENSMUSG00000104359.1  ENSMUSG00000107088.1  \
# Protocol2
# BGISEQ-500 ESC Sequencing rep1                    0.0                   0.0
# BGISEQ-500 K562 Seuqencing rep1                   0.0                   0.0
#
#                                  ENSMUSG00000111721.1  ENSMUSG00000111588.1  \
# Protocol2
# BGISEQ-500 ESC Sequencing rep1                    0.0                   0.0
# BGISEQ-500 K562 Seuqencing rep1                   0.5                   0.0
#
#                                  ENSMUSG00000107210.1  ENSMUSG00000097359.2  \
# Protocol2
# BGISEQ-500 ESC Sequencing rep1                    0.0                   1.5
# BGISEQ-500 K562 Seuqencing rep1                   0.0                  34.5
#
#                                          ...           ENSMUSG00000083997.1  \
# Protocol2                                ...
# BGISEQ-500 ESC Sequencing rep1           ...                        0.00000
# BGISEQ-500 K562 Seuqencing rep1          ...                        6.11582
#
#                                  ENSMUSG00000111337.1  ENSMUSG00000109159.1  \
# Protocol2
# BGISEQ-500 ESC Sequencing rep1                1.00150                   0.0
# BGISEQ-500 K562 Seuqencing rep1              40.14731                   1.0
#
#                                  ENSMUSG00000107243.1  ENSMUSG00000110425.1  \
# Protocol2
# BGISEQ-500 ESC Sequencing rep1                    0.0                 3.000
# BGISEQ-500 K562 Seuqencing rep1                   4.0                56.755
#
#                                  ENSMUSG00000066315.9  ENSMUSG00000073771.11  \
# Protocol2
# BGISEQ-500 ESC Sequencing rep1           93910.630000             3727.07596
# BGISEQ-500 K562 Seuqencing rep1            903.504673               68.28600
#
#                                  ENSMUSG00000107035.1  ENSMUSG00000080242.5  \
# Protocol2
# BGISEQ-500 ESC Sequencing rep1              435.45573             8266.4670
# BGISEQ-500 K562 Seuqencing rep1             154.03886             4619.9553
#
#                                  ENSMUSG00000081408.1
# Protocol2
# BGISEQ-500 ESC Sequencing rep1                8.00000
# BGISEQ-500 K562 Seuqencing rep1               1.04841
#
# [2 rows x 34839 columns]

# %%
df1.index
# Out:
# Index(['BGISEQ-500 ESC Sequencing rep1', 'BGISEQ-500 K562 Seuqencing rep1',
#        'BGISEQ-500 SMARTer', 'BGISEQ-500 Smart-Seq2 rep1',
#        'BGISEQ-500 Smart-Seq2 rep2', 'HiSeq-2000 SMARTer',
#        'HiSeq-2000 Smart-Seq2 rep1', 'HiSeq-2000 Smart-Seq2 rep2',
#        'Hiseq4000 ESC Sequencing rep1', 'Hiseq4000 K562 Sequencing rep1'],
#       dtype='object', name='Protocol2')

# %%
l1 = df1.index[df1.index.str.startswith('BGI')].tolist()
l2 = df1.index[df1.index.str.startswith('Hi')]

# %%
l1 = ['BGISEQ-500 ESC Sequencing rep1',
 'BGISEQ-500 K562 Seuqencing rep1',
 'BGISEQ-500 SMARTer',
 'BGISEQ-500 Smart-Seq2 rep1',
 'BGISEQ-500 Smart-Seq2 rep2']

# %%
l2 = ['Hiseq4000 ESC Sequencing rep1',
 'Hiseq4000 K562 Sequencing rep1',
 'HiSeq-2000 SMARTer',
 'HiSeq-2000 Smart-Seq2 rep1',
 'HiSeq-2000 Smart-Seq2 rep2']

# %%
names = []
corrs = []
for i,j in zip(l1,l2):
    cor = df1.loc[i].corr(df1.loc[j], method='pearson')
    corrs.append(cor)
    names.append(i.replace('BGISEQ-500 ',''))

# %%
df = pd.DataFrame({'name':names,'corr':corrs})

# %% [markdown]
# > This is the pseudobulk table.

# %%
df
# Out:
#        corr                  name
# 0  0.979305   ESC Sequencing rep1
# 1  0.976184  K562 Seuqencing rep1
# 2  0.976761               SMARTer
# 3  0.966934       Smart-Seq2 rep1
# 4  0.933008       Smart-Seq2 rep2

# %%
df = pd.DataFrame(numpy.corrcoef(df1), index = df1.index, columns = df1.index)

# %% [markdown]
# > This is an all-to-all correlation table.

# %% [markdown]
# ## show a heatmap

# %%
cols =['BGISEQ-500 SMARTer', 'HiSeq-2000 SMARTer','BGISEQ-500 Smart-Seq2 rep1','HiSeq-2000 Smart-Seq2 rep1',
       'BGISEQ-500 Smart-Seq2 rep2','HiSeq-2000 Smart-Seq2 rep2','BGISEQ-500 ESC Sequencing rep1', 
       'Hiseq4000 ESC Sequencing rep1', 'BGISEQ-500 K562 Seuqencing rep1',
       'Hiseq4000 K562 Sequencing rep1']

# %%
cols =['BGISEQ-500 SMARTer', 'HiSeq-2000 SMARTer','BGISEQ-500 Smart-Seq2 rep1','HiSeq-2000 Smart-Seq2 rep1',
       'BGISEQ-500 Smart-Seq2 rep2','HiSeq-2000 Smart-Seq2 rep2']

# %%
df = df[cols]

# %%
df = df.loc[cols]

# %% [markdown]
# ## FigS1E

# %%
figsize(6,6)
fig, ax = plt.subplots()
im = ax.imshow(df.values)

# We want to show all ticks...
ax.set_xticks(np.arange(df.shape[0]))
ax.set_yticks(np.arange(df.shape[0]))
# ... and label them with the respective list entries
ax.set_xticklabels(df.index)
ax.set_yticklabels(df.index)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(df.shape[0]):
    for j in range(df.shape[0]):
        text = ax.text(j, i, '%.2f'%df.iloc[i, j],
                       ha="center", va="center", color="w")

# ax.set_title("Harvest of local farmers (in tons/year)")
fig.tight_layout()
# plt.show()
plt.savefig("Heatmap.pdf")

# %% [markdown]
# ## FigS4H

# %%
from matplotlib_venn import venn3

# %%
df = pd.read_csv("../pdata1/pseudobulk.csv", index_col=0)

# %%
df
# Out:
#                                  ENSMUSG00000107196.1  ENSMUSG00000106901.1  \
# Protocol2
# BGISEQ-500 ESC Sequencing rep1               0.000000              0.000000
# BGISEQ-500 K562 Seuqencing rep1              0.500000              0.000000
# BGISEQ-500 SMARTer                           0.000030              0.499806
# BGISEQ-500 Smart-Seq2 rep1                   0.500000              0.000000
# BGISEQ-500 Smart-Seq2 rep2                   0.500000              0.000000
# HiSeq-2000 SMARTer                           0.332127              0.000000
# HiSeq-2000 Smart-Seq2 rep1                   0.000000              0.500000
# HiSeq-2000 Smart-Seq2 rep2                   0.000000              0.000000
# Hiseq4000 ESC Sequencing rep1                0.000000              0.000000
# Hiseq4000 K562 Sequencing rep1               0.000000              0.000000
#
#                                  ENSMUSG00000107077.1  ENSMUSG00000097549.2  \
# Protocol2
# BGISEQ-500 ESC Sequencing rep1               0.000000                   0.0
# BGISEQ-500 K562 Seuqencing rep1             14.012700                   0.0
# BGISEQ-500 SMARTer                           4.350594                   0.0
# BGISEQ-500 Smart-Seq2 rep1                   1.000000                   0.0
# BGISEQ-500 Smart-Seq2 rep2                   0.000000                   0.0
# HiSeq-2000 SMARTer                           1.681241                   0.0
# HiSeq-2000 Smart-Seq2 rep1                   0.666667                   0.0
# HiSeq-2000 Smart-Seq2 rep2                   0.176734                   0.0
# Hiseq4000 ESC Sequencing rep1                0.000000                   0.0
# Hiseq4000 K562 Sequencing rep1               4.333330                   0.0
#
#                                  ENSMUSG00000104359.1  ENSMUSG00000107088.1  \
# Protocol2
# BGISEQ-500 ESC Sequencing rep1                0.00000                   0.0
# BGISEQ-500 K562 Seuqencing rep1               0.00000                   0.0
# BGISEQ-500 SMARTer                            0.00000                  49.0
# BGISEQ-500 Smart-Seq2 rep1                    0.00000                   6.5
# BGISEQ-500 Smart-Seq2 rep2                   16.70700                   0.0
# HiSeq-2000 SMARTer                            0.00000                  13.0
# HiSeq-2000 Smart-Seq2 rep1                    0.00000                   5.5
# HiSeq-2000 Smart-Seq2 rep2                    3.38753                   0.0
# Hiseq4000 ESC Sequencing rep1                 0.00000                   0.0
# Hiseq4000 K562 Sequencing rep1                0.00000                   0.0
#
#                                  ENSMUSG00000111721.1  ENSMUSG00000111588.1  \
# Protocol2
# BGISEQ-500 ESC Sequencing rep1                    0.0                   0.0
# BGISEQ-500 K562 Seuqencing rep1                   0.5                   0.0
# BGISEQ-500 SMARTer                                0.0                   4.5
# BGISEQ-500 Smart-Seq2 rep1                        0.5                  21.0
# BGISEQ-500 Smart-Seq2 rep2                        0.5                  56.5
# HiSeq-2000 SMARTer                                0.0                   0.5
# HiSeq-2000 Smart-Seq2 rep1                        0.0                   5.0
# HiSeq-2000 Smart-Seq2 rep2                        0.0                   2.5
# Hiseq4000 ESC Sequencing rep1                     0.0                   0.0
# Hiseq4000 K562 Sequencing rep1                    0.0                   0.0
#
#                                  ENSMUSG00000107210.1  ENSMUSG00000097359.2  \
# Protocol2
# BGISEQ-500 ESC Sequencing rep1                0.00000                   1.5
# BGISEQ-500 K562 Seuqencing rep1               0.00000                  34.5
# BGISEQ-500 SMARTer                            2.50142                   2.0
# BGISEQ-500 Smart-Seq2 rep1                    2.98755                   0.5
# BGISEQ-500 Smart-Seq2 rep2                    0.00000                   0.0
# HiSeq-2000 SMARTer                            1.67056                   0.5
# HiSeq-2000 Smart-Seq2 rep1                    1.12381                   0.0
# HiSeq-2000 Smart-Seq2 rep2                    0.00000                   0.0
# Hiseq4000 ESC Sequencing rep1                 0.00000                   1.5
# Hiseq4000 K562 Sequencing rep1                0.00000                   3.0
#
#                                          ...           ENSMUSG00000083997.1  \
# Protocol2                                ...
# BGISEQ-500 ESC Sequencing rep1           ...                        0.00000
# BGISEQ-500 K562 Seuqencing rep1          ...                        6.11582
# BGISEQ-500 SMARTer                       ...                       42.04011
# BGISEQ-500 Smart-Seq2 rep1               ...                        1.00317
# BGISEQ-500 Smart-Seq2 rep2               ...                       33.01779
# HiSeq-2000 SMARTer                       ...                       15.00129
# HiSeq-2000 Smart-Seq2 rep1               ...                        3.00107
# HiSeq-2000 Smart-Seq2 rep2               ...                        1.00000
# Hiseq4000 ESC Sequencing rep1            ...                        1.00173
# Hiseq4000 K562 Sequencing rep1           ...                        3.08179
#
#                                  ENSMUSG00000111337.1  ENSMUSG00000109159.1  \
# Protocol2
# BGISEQ-500 ESC Sequencing rep1                1.00150                   0.0
# BGISEQ-500 K562 Seuqencing rep1              40.14731                   1.0
# BGISEQ-500 SMARTer                           24.06719                   2.0
# BGISEQ-500 Smart-Seq2 rep1                   12.03787                   0.0
# BGISEQ-500 Smart-Seq2 rep2                    2.00152                   0.0
# HiSeq-2000 SMARTer                            3.00726                   0.0
# HiSeq-2000 Smart-Seq2 rep1                    4.39114                   0.0
# HiSeq-2000 Smart-Seq2 rep2                    2.00328                   0.0
# Hiseq4000 ESC Sequencing rep1                 0.00000                   0.0
# Hiseq4000 K562 Sequencing rep1                3.00126                   0.0
#
#                                  ENSMUSG00000107243.1  ENSMUSG00000110425.1  \
# Protocol2
# BGISEQ-500 ESC Sequencing rep1                    0.0              3.000000
# BGISEQ-500 K562 Seuqencing rep1                   4.0             56.755000
# BGISEQ-500 SMARTer                                0.0             15.000000
# BGISEQ-500 Smart-Seq2 rep1                        0.0             13.677450
# BGISEQ-500 Smart-Seq2 rep2                        1.0              6.000000
# HiSeq-2000 SMARTer                                0.0              4.000000
# HiSeq-2000 Smart-Seq2 rep1                        0.0              4.000000
# HiSeq-2000 Smart-Seq2 rep2                        0.0              1.000000
# Hiseq4000 ESC Sequencing rep1                     0.0              4.000000
# Hiseq4000 K562 Sequencing rep1                    1.0             43.603843
#
#                                  ENSMUSG00000066315.9  ENSMUSG00000073771.11  \
# Protocol2
# BGISEQ-500 ESC Sequencing rep1           93910.630000             3727.07596
# BGISEQ-500 K562 Seuqencing rep1            903.504673               68.28600
# BGISEQ-500 SMARTer                        5876.940684             7344.42980
# BGISEQ-500 Smart-Seq2 rep1              112372.769161             7700.67955
# BGISEQ-500 Smart-Seq2 rep2              395535.680900             7341.01971
# HiSeq-2000 SMARTer                         197.692855             2872.91187
# HiSeq-2000 Smart-Seq2 rep1                2911.986450             2988.47902
# HiSeq-2000 Smart-Seq2 rep2                1792.305916             2115.65041
# Hiseq4000 ESC Sequencing rep1            59157.470000             1528.69916
# Hiseq4000 K562 Sequencing rep1             529.447774               14.00000
#
#                                  ENSMUSG00000107035.1  ENSMUSG00000080242.5  \
# Protocol2
# BGISEQ-500 ESC Sequencing rep1             435.455730           8266.467000
# BGISEQ-500 K562 Seuqencing rep1            154.038860           4619.955300
# BGISEQ-500 SMARTer                          89.347747          25920.176150
# BGISEQ-500 Smart-Seq2 rep1                 195.736000          31699.557991
# BGISEQ-500 Smart-Seq2 rep2                 453.187161          41082.168500
# HiSeq-2000 SMARTer                          10.559021           6365.110330
# HiSeq-2000 Smart-Seq2 rep1                  37.819600           8361.767588
# HiSeq-2000 Smart-Seq2 rep2                  47.958863           5248.961560
# Hiseq4000 ESC Sequencing rep1              121.437330           6019.610000
# Hiseq4000 K562 Sequencing rep1              32.433880           2304.653200
#
#                                  ENSMUSG00000081408.1
# Protocol2
# BGISEQ-500 ESC Sequencing rep1                8.00000
# BGISEQ-500 K562 Seuqencing rep1               1.04841
# BGISEQ-500 SMARTer                            5.00000
# BGISEQ-500 Smart-Seq2 rep1                    3.00100
# BGISEQ-500 Smart-Seq2 rep2                    0.00000
# HiSeq-2000 SMARTer                            2.00000
# HiSeq-2000 Smart-Seq2 rep1                    1.00000
# HiSeq-2000 Smart-Seq2 rep2                    0.00000
# Hiseq4000 ESC Sequencing rep1                 1.00000
# Hiseq4000 K562 Sequencing rep1                0.00000
#
# [10 rows x 34839 columns]

# %%
df.shape
# Out:
# (10, 34839)

# %%
from matplotlib_venn import venn2

# %%
i=0
print(df.index[i])
venn2([set(df.loc[l1[i]][df.loc[l1[i]]>0].index), set(df.loc[l2[i]][df.loc[l2[i]]>0].index)])
# Out:
# BGISEQ-500 ESC Sequencing rep1

# %%
i=1
print(df.index[i])
venn2([set(df.loc[l1[i]][df.loc[l1[i]]>0].index), set(df.loc[l2[i]][df.loc[l2[i]]>0].index)])
# Out:
# BGISEQ-500 K562 Seuqencing rep1

# %%
# print(df.index[i])
name1 = 'BGISEQ-500 K562 Seuqencing rep1'
name2 = 'BGISEQ-500 ESC Sequencing rep1'
venn2([set(df.loc[name1][df.loc[name1]>10].index), set(df.loc[name2][df.loc[name2]>10].index)],set_labels=(name1,name2))

# %%
# print(df.index[i])
name1 = 'Hiseq4000 K562 Sequencing rep1'
name2 = 'Hiseq4000 ESC Sequencing rep1'
venn2([set(df.loc[name1][df.loc[name1]>10].index), set(df.loc[name2][df.loc[name2]>10].index)],set_labels=(name1,name2))

# %%
name1 = 'Hiseq4000 K562 Sequencing rep1'
name2 = 'Hiseq4000 ESC Sequencing rep1'
x1 = df.loc[name1][df.loc[name1]>10].index
x2 = df.loc[name2][df.loc[name2]>10].index
name1 = 'BGISEQ-500 K562 Seuqencing rep1'
name2 = 'BGISEQ-500 ESC Sequencing rep1'
x3 = df.loc[name1][df.loc[name1]>10].index
x4 = df.loc[name2][df.loc[name2]>10].index

# %%
overlap = x3[x3.isin(x4)]

# %%
pd.Series(overlap).to_csv("overlap.csv")

# %%
non1 = x3[~x3.isin(x4)]

# %%
pd.Series(non1).to_csv("k562only_genes.csv")

# %%
non2 = x4[~x4.isin(x3)]

# %%
pd.Series(non2).to_csv("ESConly_genes.csv")

# %%
x5 = x3[x3.isin(x1)]
x6 = x4[x4.isin(x2)]

# %%
venn2([set(x5), set(x6)],set_labels=('K562','ESC'))

# %%
i=2
print(df.index[i])
venn2([set(df.loc[l1[i]][df.loc[l1[i]]>0].index), set(df.loc[l2[i]][df.loc[l2[i]]>0].index)])
# Out:
# BGISEQ-500 SMARTer

# %%
i=3
print(df.index[i])
venn2([set(df.loc[l1[i]][df.loc[l1[i]]>0].index), set(df.loc[l2[i]][df.loc[l2[i]]>0].index)])
# Out:
# BGISEQ-500 Smart-Seq2 rep1

# %%
i=4
print(df.index[i])
venn2([set(df.loc[l1[i]][df.loc[l1[i]]>0].index), set(df.loc[l2[i]][df.loc[l2[i]]>0].index)])
# Out:
# BGISEQ-500 Smart-Seq2 rep2

# %% [markdown]
# # FigS1D CV^2 vs. Mean

# %%
dfs = []
for f in ['bgi','sanger']:
    df = pd.read_csv("../pdata1/%s.csv"%f, index_col=0)
    dfs.append(df)
df = pd.concat(dfs, axis=0)

df1 = df[df.columns[df.columns.str.startswith('ENS')|df.columns.str.startswith('Protocol2')]]

# %%
df = df1.T

# %%
names = df.loc['Protocol2'].unique()

# %%
for s in df.loc['Protocol2'].unique():
#     print(s)
    df['%s_mean'%s] = np.mean(df.loc[:,df.loc['Protocol2'] == s].iloc[:-1,:],1)
    df['%s_var'%s] = np.var(df.loc[:,df.loc['Protocol2'] == s].iloc[:-1,:],1)
    df['%s_drop'%s] = np.sum((df.loc[:,df.loc['Protocol2'] == s].iloc[:-1,:]==0),1) \
    / df.loc[:,df.loc['Protocol2'] == s].shape[1]
    df['%s_cv2'%s] = df['%s_var'%s]/(df['%s_mean'%s]**2)
df = df.iloc[:-1,:]

# %%
names
# Out:
# array(['BGISEQ-500 Smart-Seq2 rep2', 'BGISEQ-500 Smart-Seq2 rep1',
#        'BGISEQ-500 SMARTer', 'BGISEQ-500 K562 Seuqencing rep1',
#        'BGISEQ-500 ESC Sequencing rep1', 'Hiseq4000 K562 Sequencing rep1',
#        'Hiseq4000 ESC Sequencing rep1', 'HiSeq-2000 SMARTer',
#        'HiSeq-2000 Smart-Seq2 rep1', 'HiSeq-2000 Smart-Seq2 rep2'],
#       dtype=object)

# %%
namet = [['BGISEQ-500 Smart-Seq2 rep2','HiSeq-2000 Smart-Seq2 rep2'],
         ['BGISEQ-500 Smart-Seq2 rep1','HiSeq-2000 Smart-Seq2 rep1'],
         ['BGISEQ-500 SMARTer','HiSeq-2000 SMARTer'],
         ['BGISEQ-500 K562 Seuqencing rep1','Hiseq4000 K562 Sequencing rep1',],
         ['BGISEQ-500 ESC Sequencing rep1','Hiseq4000 ESC Sequencing rep1']]
titles = ['Smart-Seq2 rep2',
          'Smart-Seq2 rep1',
          'SMARTer',
          'K562',
          'ESC']

# %%
figsize(5,5)
for tt, nameu in zip(titles,namet):
    plt.clf()
    plt.loglog()
    for s in nameu:
        plt.scatter(df['%s_mean'%s], df['%s_cv2'%s], s = 0.1, label = s)
    plt.xlim(1e-6, 1e5)
    plt.ylim(1e-2, 1e2);
    plt.legend(bbox_to_anchor=(1.05, 1))
    plt.title(tt)
    plt.xlabel("Means")
    plt.ylabel("$CV^2$")
    plt.show()

# %% [markdown]
# ## Fig S1D (Dropouts vs. Means)

# %%
for tt, nameu in zip(titles,namet):
    plt.clf()
    plt.xscale('log')
    for s in nameu:
        plt.scatter(df['%s_mean'%s], df['%s_drop'%s], s = 0.1, label = s)
    plt.xlim(1e-5, 1e5)
    plt.ylim(-0.1, 1.1);
    plt.legend(bbox_to_anchor=(1.05, 1))
    plt.xlabel("Means")
    plt.ylabel("Dropout rate")
    plt.show()

# %% [markdown]
# # Fig S1D (Fagment Length)

# %%
df1 = pd.read_csv("../data/fLen_bgi.csv", index_col=0)
df2 = pd.read_csv("../data/fLen_sanger.csv", index_col=0)

df = pd.concat([df1,df2])

df.index = df.index.str.split('/').str[-1]

# %%
df['Protocol2'] = phn.loc[df.index]['Protocol2']
df = df[~df.Protocol2.isna()]

# %%
df.shape
# Out:
# (630, 1002)

# %%
df.columns = list(arange(1001)+1)+['Protocol2']

# %%
df['Protocol2'] = df['Protocol2'].str.replace('Seuqencing','Sequencing')

# %%
df.Protocol2.value_counts()
# Out:
# HiSeq-2000 Smart-Seq2 rep1         96
# BGISEQ-500 SMARTer                 96
# HiSeq-2000 SMARTer                 95
# BGISEQ-500 Smart-Seq2 rep1         95
# BGISEQ-500 Smart-Seq2 rep2         72
# HiSeq-2000 Smart-Seq2 rep2         60
# Hiseq4000 K562 Sequencing rep1     37
# BGISEQ-500 K562 Sequencing rep1    37
# Hiseq4000 ESC Sequencing rep1      21
# BGISEQ-500 ESC Sequencing rep1     21
# Name: Protocol2, dtype: int64

# %%
colors = [matplotlib.colors.rgb2hex(plt.get_cmap("Paired")(i)) for i in range(0,10)]

# %%
cc = dict(zip(df.Protocol2.unique(),colors))

# %%
figsize(5,5)
df1 = df[df.Protocol2.str.endswith('Smart-Seq2 rep1')]
for i in arange(df1.shape[0]):
    plt.scatter(arange(1001)+1, df1.iloc[i][:-1], s = 0.1, label = df1.iloc[i][-1], c = cc[df1.iloc[i][-1]])
plt.xlabel('length %', fontsize=18)
plt.ylabel('density', fontsize=18)
plt.xticks([0,200,400,600,800,1000],[0,20,40,60,80,100])
# Out:
# ([<matplotlib.axis.XTick at 0x1268aad68>,
#   <matplotlib.axis.XTick at 0x1268aa668>,
#   <matplotlib.axis.XTick at 0x1268aa3c8>,
#   <matplotlib.axis.XTick at 0x12693bcc0>,
#   <matplotlib.axis.XTick at 0x10a2bf128>,
#   <matplotlib.axis.XTick at 0x10a2bf588>],
#  <a list of 6 Text xticklabel objects>)

# %%
figsize(5,5)
df1 = df[df.Protocol2.str.endswith('Smart-Seq2 rep2')]
for i in arange(df1.shape[0]):
    plt.scatter(arange(1001)+1, df1.iloc[i][:-1], s = 0.1, label = df1.iloc[i][-1], c = cc[df1.iloc[i][-1]])
plt.xlabel('length %', fontsize=18)
plt.ylabel('density', fontsize=18)
plt.xticks([0,200,400,600,800,1000],[0,20,40,60,80,100])
# Out:
# ([<matplotlib.axis.XTick at 0x126a2dba8>,
#   <matplotlib.axis.XTick at 0x126a2d588>,
#   <matplotlib.axis.XTick at 0x126a2d048>,
#   <matplotlib.axis.XTick at 0x126e2af28>,
#   <matplotlib.axis.XTick at 0x126ab3438>,
#   <matplotlib.axis.XTick at 0x126e2a5c0>],
#  <a list of 6 Text xticklabel objects>)

# %%
figsize(5,5)
df1 = df[df.Protocol2.str.endswith('SMARTer')]
for i in arange(df1.shape[0]):
    plt.scatter(arange(1001)+1, df1.iloc[i][:-1], s = 0.1, label = df1.iloc[i][-1], c = cc[df1.iloc[i][-1]])
plt.xlabel('length %', fontsize=18)
plt.ylabel('density', fontsize=18)
plt.xticks([0,200,400,600,800,1000],[0,20,40,60,80,100])
# Out:
# ([<matplotlib.axis.XTick at 0x126e6cfd0>,
#   <matplotlib.axis.XTick at 0x126e6c908>,
#   <matplotlib.axis.XTick at 0x126e6c2e8>,
#   <matplotlib.axis.XTick at 0x126f0a1d0>,
#   <matplotlib.axis.XTick at 0x12a3d4f98>,
#   <matplotlib.axis.XTick at 0x12721d588>],
#  <a list of 6 Text xticklabel objects>)

# %%
figsize(5,5)
df1 = df[df.Protocol2.str.endswith('ESC Sequencing rep1')]
for i in arange(df1.shape[0]):
    plt.scatter(arange(1001)+1, df1.iloc[i][:-1], s = 0.1, label = df1.iloc[i][-1], c = cc[df1.iloc[i][-1]])
plt.xlabel('length %', fontsize=18)
plt.ylabel('density', fontsize=18)
plt.xticks([0,200,400,600,800,1000],[0,20,40,60,80,100])
# Out:
# ([<matplotlib.axis.XTick at 0x12a494b00>,
#   <matplotlib.axis.XTick at 0x12a494438>,
#   <matplotlib.axis.XTick at 0x12a494198>,
#   <matplotlib.axis.XTick at 0x12a4bcb70>,
#   <matplotlib.axis.XTick at 0x12a582048>,
#   <matplotlib.axis.XTick at 0x12a582cc0>],
#  <a list of 6 Text xticklabel objects>)

# %%
figsize(5,5)
df1 = df[df.Protocol2.str.endswith('K562 Sequencing rep1')]
for i in arange(df1.shape[0]):
    plt.scatter(arange(1001)+1, df1.iloc[i][:-1], s = 0.1, label = df1.iloc[i][-1], c = cc[df1.iloc[i][-1]])
plt.xlabel('length %', fontsize=18)
plt.ylabel('density', fontsize=18)
plt.xticks([0,200,400,600,800,1000],[0,20,40,60,80,100])
# Out:
# ([<matplotlib.axis.XTick at 0x12a6a6438>,
#   <matplotlib.axis.XTick at 0x12a6a2d68>,
#   <matplotlib.axis.XTick at 0x12a6a2ac8>,
#   <matplotlib.axis.XTick at 0x12a6e5780>,
#   <matplotlib.axis.XTick at 0x12a6e5c50>,
#   <matplotlib.axis.XTick at 0x12a6e5c18>],
#  <a list of 6 Text xticklabel objects>)

# %% [markdown]
# # Fig S1D (Coverage over average gene)

# %%
phn = pd.read_csv("../data/phn.csv",index_col=0)

# %%
df = pd.read_csv("gbc.csv", index_col=0, header=None, sep='\t')
df = df[~df.index.str.startswith('Per')]
df.index = df.index.str.split('.').str[0]

# %%
df.shape
# Out:
# (687, 100)

# %%
df1  =df.loc[df.index.isin(phn.index)]

# %%
df1.shape
# Out:
# (629, 100)

# %%
phn.shape
# Out:
# (1238, 11)

# %%
phn1 = phn.loc[df1.index]

# %%
phn1.shape
# Out:
# (629, 11)

# %%
phn1.head()
# Out:
#                               Batch  Cell Cell_line            Fullname  \
# 0
# CL100029125_L01_11  Smart-Seq2 rep2    26       ESC  Smart-Seq2 rep2_26
# CL100029125_L01_12  Smart-Seq2 rep2    38       ESC  Smart-Seq2 rep2_38
# CL100029125_L01_14  Smart-Seq2 rep2    62       ESC  Smart-Seq2 rep2_62
# CL100029125_L01_15  Smart-Seq2 rep2    74       ESC  Smart-Seq2 rep2_74
# CL100029125_L01_16  Smart-Seq2 rep2    86       ESC  Smart-Seq2 rep2_86
#
#                     Place    Platform    Protocol                   Protocol2  \
# 0
# CL100029125_L01_11  China  BGISEQ-500  Smart-Seq2  BGISEQ-500 Smart-Seq2 rep2
# CL100029125_L01_12  China  BGISEQ-500  Smart-Seq2  BGISEQ-500 Smart-Seq2 rep2
# CL100029125_L01_14  China  BGISEQ-500  Smart-Seq2  BGISEQ-500 Smart-Seq2 rep2
# CL100029125_L01_15  China  BGISEQ-500  Smart-Seq2  BGISEQ-500 Smart-Seq2 rep2
# CL100029125_L01_16  China  BGISEQ-500  Smart-Seq2  BGISEQ-500 Smart-Seq2 rep2
#
#                    Read_type Well           repeat
# 0
# CL100029125_L01_11     PE100   C2  Smart-Seq2 rep2
# CL100029125_L01_12     PE100   D2  Smart-Seq2 rep2
# CL100029125_L01_14     PE100   F2  Smart-Seq2 rep2
# CL100029125_L01_15     PE100   G2  Smart-Seq2 rep2
# CL100029125_L01_16     PE100   H2  Smart-Seq2 rep2

# %%
df1['Protocol2'] = phn1['Protocol2']

# %%
df= df1

# %%
cc
# Out:
# {'BGISEQ-500 Smart-Seq2 rep2': '#a6cee3',
#  'BGISEQ-500 Smart-Seq2 rep1': '#1f78b4',
#  'BGISEQ-500 SMARTer': '#b2df8a',
#  'BGISEQ-500 K562 Sequencing rep1': '#33a02c',
#  'BGISEQ-500 ESC Sequencing rep1': '#fb9a99',
#  'Hiseq4000 K562 Sequencing rep1': '#e31a1c',
#  'Hiseq4000 ESC Sequencing rep1': '#fdbf6f',
#  'HiSeq-2000 SMARTer': '#ff7f00',
#  'HiSeq-2000 Smart-Seq2 rep2': '#cab2d6',
#  'HiSeq-2000 Smart-Seq2 rep1': '#6a3d9a'}

# %%
figsize(5,5)
df1 = df[df.Protocol2.str.endswith('Smart-Seq2 rep1')]
dd = df1.Protocol2.value_counts().to_dict()
labs = []
for i in arange(df1.shape[0]):
    label = '%s %d'%(df1.iloc[i][-1],dd[df1.iloc[i][-1]])
    if label in labs:
        plt.plot(np.linspace(1, 100, 100), df1.iloc[i][:-1]/df1.iloc[i][:-1].sum(), label='', c = cc[df1.iloc[i][-1]],\
             alpha=0.2)
    else:
        plt.plot(np.linspace(1, 100, 100), df1.iloc[i][:-1]/df1.iloc[i][:-1].sum(), label = label, c = cc[df1.iloc[i][-1]],\
             alpha=0.2)
        labs.append(label)
plt.legend()
plt.xlabel('length %', fontsize=18)
plt.ylabel('density', fontsize=18)
# Out:
# Text(0,0.5,'density')

# %%
figsize(5,5)
df1 = df[df.Protocol2.str.endswith('Smart-Seq2 rep2')]
dd = df1.Protocol2.value_counts().to_dict()
labs = []
for i in arange(df1.shape[0]):
    label = '%s %d'%(df1.iloc[i][-1],dd[df1.iloc[i][-1]])
    if label in labs:
        plt.plot(np.linspace(1, 100, 100), df1.iloc[i][:-1]/df1.iloc[i][:-1].sum(), label='', c = cc[df1.iloc[i][-1]],\
             alpha=0.2)
    else:
        plt.plot(np.linspace(1, 100, 100), df1.iloc[i][:-1]/df1.iloc[i][:-1].sum(), label = label, c = cc[df1.iloc[i][-1]],\
             alpha=0.2)
        labs.append(label)
plt.legend()
plt.xlabel('length %', fontsize=18)
plt.ylabel('density', fontsize=18)
# Out:
# Text(0,0.5,'density')

# %%
figsize(5,5)
df1 = df[df.Protocol2.str.endswith('SMARTer')]
dd = df1.Protocol2.value_counts().to_dict()
labs = []
for i in arange(df1.shape[0]):
    label = '%s %d'%(df1.iloc[i][-1],dd[df1.iloc[i][-1]])
    if label in labs:
        plt.plot(np.linspace(1, 100, 100), df1.iloc[i][:-1]/df1.iloc[i][:-1].sum(), label='', c = cc[df1.iloc[i][-1]],\
             alpha=0.2)
    else:
        plt.plot(np.linspace(1, 100, 100), df1.iloc[i][:-1]/df1.iloc[i][:-1].sum(), label = label, c = cc[df1.iloc[i][-1]],\
             alpha=0.2)
        labs.append(label)
plt.legend()
plt.xlabel('length %', fontsize=18)
plt.ylabel('density', fontsize=18)
# Out:
# Text(0,0.5,'density')

# %% [markdown]
# # End
